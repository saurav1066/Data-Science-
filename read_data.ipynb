# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/80-cereals/cereal.csv
# /kaggle/input/country-gdp/countries.csv
# /kaggle/input/premier-league-2022-2023/epl_results_2022-23.csv
# /kaggle/input/premier-league-2022-2023/epl_clubs_info_2022-23.csv

# %%
#reading a csv data as a pandas dataframe
data = pd.read_csv('/kaggle/input/premier-league-2022-2023/epl_results_2022-23.csv')
print(data)
#summarizing the data 
data.describe()
# Out:
#     Div        Date   Time        HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 0    E0  05/08/2022  20:00  Crystal Palace         Arsenal     0     2   A
# 1    E0  06/08/2022  12:30          Fulham       Liverpool     2     2   D
# 2    E0  06/08/2022  15:00     Bournemouth     Aston Villa     2     0   H
# 3    E0  06/08/2022  15:00           Leeds          Wolves     2     1   H
# 4    E0  06/08/2022  15:00       Newcastle      Nottingham     2     0   H
# ..   ..         ...    ...             ...             ...   ...   ...  ..
# 291  E0  08/04/2023  15:00       Tottenham        Brighton     2     1   H
# 292  E0  08/04/2023  15:00          Wolves         Chelsea     1     0   H
# 293  E0  08/04/2023  17:30     Southampton        Man City     1     4   A
# 294  E0  09/04/2023  14:00           Leeds  Crystal Palace     1     5   A
# 295  E0  09/04/2023  16:30       Liverpool         Arsenal     2     2   D
#
#      HTHG  HTAG  ... HST AST  HF  AF  HC  AC  HY  AY  HR  AR
# ...

# %%
import matplotlib.pyplot as plt #data visualization with pyplot

#Plotting numerical variable using a histogram using a numerical dataset
numerical_data = pd.read_csv('/kaggle/input/country-gdp/countries.csv')

#plotting a bar chart 
countries = numerical_data["Country"]
gdp  = numerical_data["GDP_per_capita"]

plt.bar(countries[0:5],gdp[0:5])
plt.title("Histogram for GDP-per-capita for top 5 ranked countries")
plt.xlabel("Countries")
plt.ylabel("GDP_per_capita in US($)")
# Out:
# Text(0, 0.5, 'GDP_per_capita in US($)')

# %%
#Performing a t-test
#to check if a numerical value is between two groups
#if we want to do a comparision between more than two groups then we can use an extension of t-test named"ANOVA"

#importing modules for t-test
from scipy.stats import ttest_ind

#usable datasets : that has one numerical variable measured for two groups
cereal_data = pd.read_csv('/kaggle/input/80-cereals/cereal.csv')
print(cereal_data)


#Getting sugar content for Q and G manufactured cereals
Q_manufactured = cereal_data['sugars'][cereal_data['mfr'] == "Q"]
print(Q_manufactured)
G_manufactured = cereal_data['sugars'][cereal_data['mfr'] == "G"]


#comparision
ttest_ind(G_manufactured,Q_manufactured, equal_var=False)

#Histograms for both classes of data
plt.hist(Q_manufactured,label = "Q")
plt.hist(G_manufactured, label = "G")
plt.legend(loc = 'upper right')
plt.title("Histogram for Sugar content of Q and G manufactured cereals")
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...
